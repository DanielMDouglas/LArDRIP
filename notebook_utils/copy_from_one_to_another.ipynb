# %%
import shutil
import os

# Source and destination directories
source_dir = '/global/cfs/projectdirs/dune/www/data/2x2/simulation/silentc_work/point_mae_old/Point-MAE/data/edepsim_npys/edepsim_pc'  # Replace with your source directory
destination_dir = '/global/cfs/projectdirs/dune/www/data/2x2/simulation/silentc_work/point_mae/Point-MAE/data/edepsim_npys/edepsim_pc'  # Replace with your destination directory

# Iterate through the range of numbers (311 to 388) and copy the files
for i in range(311, 389):  # 389 is exclusive in Python range function
    file_name = f'04401088-{i}.npy'
    source_file = os.path.join(source_dir, file_name)
    destination_file = os.path.join(destination_dir, file_name)

    if os.path.exists(source_file):
        shutil.copy(source_file, destination_file)
        print(f'Copied: {file_name}')
    else:
        print(f'File not found: {file_name}')
# Out:
# Copied: 04401088-311.npy
# Copied: 04401088-312.npy
# Copied: 04401088-313.npy
# Copied: 04401088-314.npy
# Copied: 04401088-315.npy
# Copied: 04401088-316.npy
# Copied: 04401088-317.npy
# Copied: 04401088-318.npy
# Copied: 04401088-319.npy
# Copied: 04401088-320.npy
# Copied: 04401088-321.npy
# Copied: 04401088-322.npy
# Copied: 04401088-323.npy
# Copied: 04401088-324.npy
# Copied: 04401088-325.npy
# Copied: 04401088-326.npy
# Copied: 04401088-327.npy
# Copied: 04401088-328.npy
# Copied: 04401088-329.npy
# Copied: 04401088-330.npy
# Copied: 04401088-331.npy
# Copied: 04401088-332.npy
# Copied: 04401088-333.npy
# Copied: 04401088-334.npy
# Copied: 04401088-335.npy
# Copied: 04401088-336.npy
# Copied: 04401088-337.npy
# Copied: 04401088-338.npy
# Copied: 04401088-339.npy
# Copied: 04401088-340.npy
# Copied: 04401088-341.npy
# Copied: 04401088-342.npy
# Copied: 04401088-343.npy
# Copied: 04401088-344.npy
# Copied: 04401088-345.npy
# Copied: 04401088-346.npy
# Copied: 04401088-347.npy
# ...
